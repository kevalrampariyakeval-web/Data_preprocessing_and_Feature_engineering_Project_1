# %% [markdown]
# # Data Preprocessing and Feature Engineering Project
#
# ## Part A: Theory Questions

# %% [markdown]
# ### 1. What is Data Analysis?
# Data Analysis is the process of collecting, organizing, cleaning, transforming, and interpreting data to discover useful information, patterns, and insights for better decision-making.

# %% [markdown]
# ### 2. Steps of a Data Science Project
# 1. Problem Understanding
# 2. Data Collection
# 3. Data Cleaning
# 4. Exploratory Data Analysis (EDA)
# 5. Feature Engineering
# 6. Model Building
# 7. Model Evaluation
# 8. Deployment

# %% [markdown]
# ### 3. Machine Learning Problem Statement
# Predict whether a customer will churn based on purchase behavior, age, income, and purchasing activity.

# %% [markdown]
# ### 4. What are Tensors?
# Tensors are multi-dimensional arrays used in machine learning and deep learning.
# - Scalar = 0D Tensor
# - Vector = 1D Tensor
# - Matrix = 2D Tensor
# - Higher-dimensional arrays = 3D+ Tensor

# %%
import numpy as np
scalar = np.array(10)
vector = np.array([1,2,3])
matrix = np.array([[1,2],[3,4]])
print(scalar)
print(vector)
print(matrix)

# %% [markdown]
# # Part B: Data Acquisition

# %%
import pandas as pd
import sqlite3
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Load CSV File

# %%
df_csv = pd.read_csv('ipl_dataset.csv')
df_csv.head()

# %% [markdown]
# ## 2. Load JSON File

# %%
with open('dummy_data.json', 'r') as file:
    json_data = json.load(file)
df_json = pd.DataFrame(json_data)
df_json.head()

# %% [markdown]
# ## 3. Connect SQL Database

# %%
conn = sqlite3.connect('ecommerce.db')
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
tables

# %% [markdown]
# ## 4. Fetch API Data (Free Dummy API)

# %%
url = 'https://jsonplaceholder.typicode.com/users'
response = requests.get(url)
api_data = response.json()
df_api = pd.DataFrame(api_data)
df_api.head()

# %% [markdown]
# # Part C: Data Understanding and Cleaning

# %%
df_csv.head()
df_csv.info()
df_csv.describe()

# %% [markdown]
# ## Missing Values and Duplicate Values

# %%
df_csv.isnull().sum()
df_csv.duplicated().sum()

# %% [markdown]
# ## Data Cleaning

# %%
df_csv.drop_duplicates(inplace=True)
df_csv.dropna(inplace=True)

# %% [markdown]
# # Part D: Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Univariate Analysis

# %%
df_csv.hist(figsize=(12,8))
plt.show()

# %% [markdown]
# ## Multivariate Analysis - Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_csv.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# # Part E: Data Profiling

# %%
from ydata_profiling import ProfileReport
import pandas as pd


df = pd.read_csv("ipl_dataset.csv")


profile = ProfileReport(
    df,
    title="IPL Dataset Profiling Report",
    explorative=True
)


profile.to_file("ipl_dataset_profiling_report.html")
# Out:
# Summarize dataset:  88%|████████▊ | 35/40 [00:01<00:00, 12.65it/s, Calculate auto correlation]       c:\Users\jines\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Rajasthan Royals'')
#   warnings.warn(
# Summarize dataset:  98%|█████████▊| 294/299 [00:45<00:01,  3.03it/s, Missing diagram heatmap]               c:\Users\jines\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
# ...
